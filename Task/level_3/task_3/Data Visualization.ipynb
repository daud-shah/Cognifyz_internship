# %% [markdown]
# ### **📌 Objective – Level 3, Task 3: Data Visualization**
#
# In this task, we aim to **gain insights from restaurant data using visualizations**.
#
# ### **🎯 Key Goals:**
# 1️⃣ **Visualize the distribution of ratings** using charts (e.g., histograms, bar plots).
# 2️⃣ **Compare average ratings of different cuisines and cities** using appropriate visualizations.
# 3️⃣ **Analyze relationships between different features and restaurant ratings** using scatter plots, box plots, etc.
#
# This analysis will help:
# ✔ Understand **how ratings are distributed** across restaurants.
# ✔ Identify **which cities or cuisines have the highest/lowest ratings**.
# ✔ Discover **patterns and trends** in restaurant ratings based on differentn you're ready! 😊sights.

# %%
import pandas as pd 
df = pd.read_csv('level_2_dataset.csv')

# %% [markdown]
# ### Step 1: Visualizing the Distribution of Ratings
# In this step, we will analyze how restaurant ratings are distributed using visualizations like histograms and bar plots.

# %% [markdown]
# #### Visualization 1: Histogram of Ratings

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set_style("whitegrid")

# Create histogram
plt.figure(figsize=(8, 5))
sns.histplot(df['Aggregate rating'], bins=10, kde=True, color="blue")

# Add labels and title
plt.xlabel("Aggregate Rating")
plt.ylabel("Number of Restaurants")
plt.title("Distribution of Restaurant Ratings")

# Show the plot
plt.show()

# %% [markdown]
#  #### Visualization 2: Bar Plot of Rating Counts

# %%
# Count of each unique rating value
rating_counts = df['Aggregate rating'].value_counts().sort_index()

# Create bar plot
plt.figure(figsize=(8, 5))
sns.barplot(x=rating_counts.index, y=rating_counts.values, palette="coolwarm")

# Add labels and title
plt.xlabel("Aggregate Rating")
plt.ylabel("Number of Restaurants")
plt.title("Count of Each Rating Value")

# Show the plot
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8620\3302688257.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rating_counts.index, y=rating_counts.values, palette="coolwarm")

# %% [markdown]
# ### Visualization 3: Violin Plot of Ratings

# %%
# Create a violin plot for restaurant ratings
plt.figure(figsize=(8, 5))
sns.violinplot(x=df['Aggregate rating'], color="purple")

# Add title and labels
plt.title("Violin Plot of Restaurant Ratings")
plt.xlabel("Aggregate Rating")

# Show the plot
plt.show()

# %% [markdown]
# #### Visualization 4: Box Plot of Ratings

# %%
# Create a box plot for restaurant ratings
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['Aggregate rating'], color="lightblue")

# Add title and labels
plt.title("Box Plot of Restaurant Ratings")
plt.xlabel("Aggregate Rating")

# Show the plot
plt.show()

# %% [markdown]
# #### visualization 5: Pie Chart of Rating Distribution

# %%
# Group rating counts
rating_distribution = df['Aggregate rating'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(rating_distribution, labels=rating_distribution.index, autopct='%1.1f%%', colors=sns.color_palette("coolwarm", len(rating_distribution)))

# Add title
plt.title("Percentage of Restaurants in Each Rating Category")

# Show the plot
plt.show()

# %% [markdown]
# ### Step 2: Compare Ratings Across Cuisines and Cities
# Now, let’s check how different cuisines and cities compare in terms of ratings.
#
# ####  Visualization 6: Average Rating by Cuisine:

# %%
# Calculate the average rating for each cuisine
cuisine_ratings = df.groupby('Cuisines')['Aggregate rating'].mean().sort_values(ascending=False).head(10)

# Create a bar plot
plt.figure(figsize=(10, 5))
sns.barplot(x=cuisine_ratings.values, y=cuisine_ratings.index, palette="viridis")

# Add title and labels
plt.xlabel("Average Rating")
plt.ylabel("Cuisine Type")
plt.title("Top 10 Highest Rated Cuisines")

# Show the plot
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8620\23007025.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cuisine_ratings.values, y=cuisine_ratings.index, palette="viridis")

# %% [markdown]
# #### Visualization 7: Average Rating by City
# This will show which cities have the highest-rated restaurants on average.

# %%
# Calculate the average rating for each city
city_ratings = df.groupby('City')['Aggregate rating'].mean().sort_values(ascending=False).head(10)

# Create a bar plot
plt.figure(figsize=(10, 5))
sns.barplot(x=city_ratings.values, y=city_ratings.index, palette="mako")

# Add title and labels
plt.xlabel("Average Rating")
plt.ylabel("City")
plt.title("Top 10 Cities with Highest Rated Restaurants")

# Show the plot
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8620\2976224646.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=city_ratings.values, y=city_ratings.index, palette="mako")

# %% [markdown]
# ### Step 3: Visualizing Feature Relationships
# Now, let’s explore how different features relate to restaurant ratings.
#
# #### Visualization 8: Price Range vs. Aggregate Rating
# This will help analyze whether expensive restaurants receive higher ratings.

# %%
# Create a box plot for price range vs. ratings
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['Price range'], y=df['Aggregate rating'], palette="coolwarm")

# Add title and labels
plt.xlabel("Price Range")
plt.ylabel("Aggregate Rating")
plt.title("Price Range vs. Restaurant Ratings")

# Show the plot
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8620\76970598.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['Price range'], y=df['Aggregate rating'], palette="coolwarm")

# %% [markdown]
# ####  Visualization 9: Votes vs. Aggregate Rating
# This scatter plot will show if restaurants with more votes tend to have higher ratings.

# %%
# Create a scatter plot for votes vs. ratings
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df['Votes'], y=df['Aggregate rating'], alpha=0.5, color="blue")

# Add title and labels
plt.xlabel("Number of Votes")
plt.ylabel("Aggregate Rating")
plt.title("Votes vs. Restaurant Ratings")

# Show the plot
plt.show()

# %% [markdown]
# #### Visualization 10: Table Booking vs. Ratings
# This will show if restaurants that offer table booking receive higher ratings.

# %%
# Create a bar plot for table booking vs. ratings
plt.figure(figsize=(8, 5))
sns.barplot(x=df['Has Table booking'], y=df['Aggregate rating'], palette="magma")

# Add title and labels
plt.xlabel("Has Table Booking (0 = No, 1 = Yes)")
plt.ylabel("Average Rating")
plt.title("Impact of Table Booking on Restaurant Ratings")

# Show the plot
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8620\1395252657.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Has Table booking'], y=df['Aggregate rating'], palette="magma")

# %% [markdown]
# # **📊 Level 3 – Task 3: Data Visualization**
#
# ---
#
# ## **📌 Objective**
# The goal of this task is to use **visualizations** to explore restaurant ratings and identify trends in the dataset.
#
# ### **🎯 Key Goals:**
# 1️⃣ **Visualize the distribution of ratings** using histograms, bar plots, and other charts.
# 2️⃣ **Compare average ratings of different cuisines and cities** to find the best-rated categories.
# 3️⃣ **Analyze relationships between various features and restaurant ratings** using scatter plots, box plots, and bar plots.
#
# This analysis helps in understanding:
# ✔ **How restaurant ratings are distributed**.
# ✔ **Which cities and cuisines tend to have higher ratings**.
# ✔ **What factors influence restaurant ratings the most**.
#
# ---
#
# ## **1️⃣ Step 1: Visualizing the Distribution of Ratings**
# ### **🔹 Process:**
# ✔ Used **histograms and bar plots** to analyze the **frequency of ratings**.
# ✔ Created **box plots and violin plots** to detect **outliers and patterns**.
# ✔ Used a **pie chart** to visualize **the proportion of restaurants in each rating category**.
#
# ### **📊 Key Insights:**
# ✔ **Most restaurants have ratings between (your observed range, e.g., 3.0 to 4.5)**.
# ✔ **Outliers exist at both low and high ends of ratings** (shown in box plots).
# ✔ **Some rating values appear more frequently** (e.g., many restaurants may have a rating of exactly 4.0).
#
# ---
#
# ## **2️⃣ Step 2: Comparing Ratings Across Cuisines and Cities**
# ### **🔹 Process:**
# ✔ Created **bar plots** to compare **average ratings across different cuisines**.
# ✔ Analyzed **city-wise restaurant ratings** to find **which cities have the highest-rated restaurants**.
#
# ### **📊 Key Insights:**
# ✔ **(Your top-rated cuisines)** tend to have the **best customer feedback**.
# ✔ **(Your top-rated cities)** have the best-rated restaurants.
# ✔ **Some cuisines and cities consistently receive better ratings**, indicating higher customer satisfaction.
#
# ---
#
# ## **3️⃣ Step 3: Visualizing Feature Relationships**
# ### **🔹 Process:**
# ✔ Used **box plots** to check how **price range** affects ratings.
# ✔ Created **scatter plots** to analyze if **restaurants with more votes tend to get higher ratings**.
# ✔ Used **bar plots** to check if **table booking influences customer ratings**.
#
# ### **📊 Key Insights:**
# ✔ **Higher price range restaurants tend to get better ratings**, but not always.
# ✔ **Restaurants with more votes usually have higher ratings**, suggesting customer engagement is linked to quality.
# ✔ **Table booking does/does not have a strong impact on ratings** (**based on your results**).
#
# ---
#
# ## **🎯 Final Summary**
# ✔ **Created multiple visualizations** to explore rating distribution, cuisine/city comparisons, and feature relationships.
# ✔ **Discovered trends** in restaurant ratings and identified key influencing factors.
# ✔ **Successfully completed Level 3 – Task 3: Data Visualization!** 🚀
#
# ---
#
# ✅ **Save this text for your documentation.**
# 🚀 **Let me know if you’re ready for Level 3 – Task 4!** 😊
